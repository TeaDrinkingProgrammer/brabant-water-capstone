# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from sklearn.preprocessing import MinMaxScaler
import numpy as np

df = pd.read_parquet('data/rucphen_precipitation_clean_updated.parquet')

# %%
def create_plot(df, x,xlabel, y, ylabel, title):
    # Create a line plot using seaborn
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=df, x = x, y = y)

    # Set labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)

    # Display the plot
    plt.show()
def show_df(df, start = pd.to_datetime('2020-02-01 08:00:00'), end = pd.to_datetime('2023-11-01 08:00:00')):
    # Define the start and end timestamps
    start_timestamp = start
    end_timestamp = end

    # Create a boolean mask for the specified time range
    mask = (df['timestamp'] >= start_timestamp) & (df['timestamp'] < end_timestamp)

    # Apply the mask to get the desired slice of the DataFrame
    result_df = df[mask]

    create_plot(result_df, 'timestamp','Timestamp', 'precipitation','mm', 'Line Plot: Rainfall over time')
    create_plot(result_df, 'timestamp','Timestamp', 'percentage','%', 'Line Plot: Percentage full over time')

# %%
# show_df(df, pd.to_datetime('2020-06-01 08:00:00'), pd.to_datetime('2023-10-01 08:00:00'))

# %%
start_timestamp = pd.to_datetime('2021-01-01 08:00:00')
end_timestamp = pd.to_datetime('2022-12-01 08:00:00')

# Create a boolean mask for the specified time range
mask = (df['timestamp'] >= start_timestamp) & (df['timestamp'] < end_timestamp)

# Apply the mask to get the desired slice of the DataFrame
df_reduced = df[mask]
df_reduced.fillna(0, inplace=True)
# show_df(df_reduced)
# Out:
# /tmp/ipykernel_458149/983979855.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_reduced.fillna(0, inplace=True)

# %%
def df_features_of_df(df: pd.DataFrame):
    # Datetime features
    # Extracting features
    df_features = df.copy()
    # df_features['percentage_delta'] = df_features['percentage'].diff()
    # df_features['percentage_delta'].fillna(0, inplace=True)
    print(df_features)

    df_features['hour'] = df_features['timestamp'].dt.hour
    df_features['dayofweek'] = df_features['timestamp'].dt.hour
    df_features['month'] = df_features['timestamp'].dt.hour

    # Define the lags you want
    # precipitation_lags = [1, 2, 3, 4, 5, 6]
    # percentage_delta_lags = [1, 2, 3, 4]
    percentage_lags = [1, 2, 3, 4, 5, 6]

    # df_features['precipitation_0-30'] = df_features['precipitation'].rolling(6, min_periods=1).sum()
    df_features['precipitation_0-60'] = df_features['precipitation'].rolling(12, min_periods=1).sum()
    df_features['precipitation_60-120'] = df_features['precipitation'].shift(13).rolling(12, min_periods=1).sum()
    # df_features['precipitation_90-120'] = df_features['precipitation'].rolling(24, min_periods=1).sum()
    
    # df_features['percentage_0-30'] = df_features['precipitation'].rolling(6, min_periods=1).sum()
    df_features['percentage_30-60'] = df_features['percentage'].shift(7).rolling(6, min_periods=1).sum()
    df_features['percentage_60-90'] = df_features['percentage'].shift(13).rolling(6, min_periods=1).sum()
    # df_features['percentage_90-120'] = df_features['precipitation'].rolling(24, min_periods=1).sum()

    # df_features['precipitation_0-180'] = df_features['precipitation'].rolling(30, min_periods=1).sum()
    # df_features['precipitation_0-240'] = df_features['precipitation'].rolling(36, min_periods=1).sum()
    # df_features['percentage_0-30'] = df_features['percentage'].rolling(6, min_periods=1).sum()
    # df_features['percentage_delta_30-60'] = df_features['percentage_delta'].shift(5).rolling(8, min_periods=1).sum()
    # df_features['percentage_delta_60-90'] = df_features['percentage_delta'].shift(13).rolling(6, min_periods=1).sum()
    # df_features['percentage_delta_90-120'] = df_features['percentage_delta'].shift(19).rolling(6, min_periods=1).sum()

    # Add lag features for 'precipitation'
    # for lag in precipitation_lags:
    #     df_features[f'precipitation_lag_{lag}'] = df_features['precipitation'].shift(lag)

    # Add lag features for 'percentage_delta'
    # for lag in percentage_delta_lags:
    #     df_features[f'percentage_delta_lag_{lag}'] = df_features['percentage_delta'].shift(lag)

    # Add lag features for 'percentage'
    for lag in percentage_lags:
        df_features[f'percentage_lag_{lag}'] = df_features['percentage'].shift(lag)

    return df_features

# %%
df_features = df_features_of_df(df_reduced)
# Drop rows with NaN values introduced by the lag operation
df_features.dropna(inplace=True)

# Reset index to integers
df_features = df_features.reset_index(drop=True)
# df_features.head()
# Out:
#                  timestamp  precipitation  percentage
# 208297 2021-01-01 08:00:00            0.0       0.000
# 208298 2021-01-01 08:05:00            0.0       0.000
# 208299 2021-01-01 08:10:00            0.0       0.000
# 208300 2021-01-01 08:15:00            0.0       0.000
# 208301 2021-01-01 08:20:00            0.0       0.000
# ...                    ...            ...         ...
# 409004 2022-12-01 07:35:00            0.0       1.754
# 409005 2022-12-01 07:40:00            0.0       1.754
# 409006 2022-12-01 07:45:00            0.0       1.754
# 409007 2022-12-01 07:50:00            0.0       1.754
# 409008 2022-12-01 07:55:00            0.0       1.754
#
# [200712 rows x 3 columns]

# %%
# Extract features and target from the DataFrame

X = df_features.copy()
# X.drop(columns=['timestamp', 'percentage', 'percentage_delta'], inplace=True)
# y = df_features['percentage_delta']

X.drop(columns=['timestamp', 'percentage'], inplace=True)
y = df_features['percentage']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y.to_numpy().reshape(-1, 1), test_size=0.5, shuffle=False)


# Standardize Data
# class MinMaxPositiveScaler:
#     def __init__(self):
#         self.min_max_scaler = MinMaxScaler()

#     def fit(self, X):
#         self.min_max_scaler.fit(X)
#         return self

#     def transform(self, X):
#         scaled_data = self.min_max_scaler.transform(X)
#         shifted_data = scaled_data + abs(np.min(scaled_data)) # Shift to make all numbers positive
#         return shifted_data
    
#     def inverse_transform(self, X):
#         scaled_data = self.min_max_scaler.inverse_transform(X)
#         shifted_data = scaled_data - abs(np.min(scaled_data))  # Shift numbers back
#         return shifted_data

#     def fit_transform(self, X):
#         self.fit(X)
#         return self.transform(X)

scaler_X = MinMaxScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

scaler_y = MinMaxScaler()
y_train_scaled = scaler_y.fit_transform(y_train)
y_test_scaled = scaler_y.transform(y_test)

def scale_X(df: pd.DataFrame):
    return scaler_X.transform(df)
def scale_y(df: pd.DataFrame):
    return scaler_y.transform(df)

# %%
# print("Number of samples in X_train_scaled:", len(X_train_scaled))
# print("Number of samples in y_train:", len(y_train_scaled))
# print("Number of samples in X_test_scaled:", len(X_test_scaled))
# print("Number of samples in y_test:", len(y_test_scaled))

y_train_scaled
# Out:
# array([[0.02632],
#        [0.02632],
#        [0.02632],
#        ...,
#        [0.     ],
#        [0.     ],
#        [0.     ]])

# %%
import optuna
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import make_scorer, mean_squared_error, r2_score
from sklearn.ensemble import AdaBoostRegressor
import xgboost as xgb
from joblib import dump, load
from pandas.api.types import CategoricalDtype  # Add this import
import optuna
import warnings

# Suppress FutureWarnings related to is_categorical_dtype
warnings.filterwarnings("ignore", category=FutureWarning, module="xgboost.data")
# Ignore the specific warning about feature names
warnings.filterwarnings("ignore", category=UserWarning, message="X does not have valid feature names")

def objective(trial):
    # Assuming X_train_scaled, y_train_scaled are already defined
    model = AdaBoostRegressor(
        n_estimators=trial.suggest_categorical('n_estimators', [5, 10, 25, 50, 100, 200]),
        learning_rate=trial.suggest_float('learning_rate', 0.01, 0.5),
        loss=trial.suggest_categorical('loss', ['linear', 'square', 'exponential'])
    )
    # TimeSeriesSplit with 5 splits
    # tscv = TimeSeriesSplit(n_splits=10)
    
    # # Define scoring using MSE only
    # scoring = make_scorer(mean_squared_error, greater_is_better=False)

    # Cross-validation
    # scores = cross_val_score(
    #     model, X_train_scaled, y_train_scaled.ravel(), cv=tscv, scoring='neg_mean_squared_error', n_jobs=20, verbose=1
    # )
    # scores_r2 = cross_val_score(
    #     model, X_train_scaled, y_train_scaled.ravel(), cv=tscv, scoring='r2', n_jobs=40, verbose=1
    # )
    model.fit(X_train, y_train.ravel())
    predictions = model.predict(X_test_scaled)
    mse = mean_squared_error(y_test_scaled.ravel(), predictions)
    r2 = r2_score(y_test_scaled.ravel(), predictions)

    # Optimize for the average MSE

    return mse, r2

train = True

if train:
    study = optuna.create_study(directions=['minimize','maximize'])
    study.optimize(objective, n_trials=100)

    # Get the best hyperparameters
    # Select the first
    best_params = study.best_trials[0].params
    
    # Print the best parameters
    for best_trial in study.best_trials:
        print(f"Best values: {best_trial.values} | best params: {best_trial.params}")
    
    # Train XGBoost Model with the best hyperparameters
    best_model = xgb.XGBRegressor(
        tree_method='gpu_hist',
        verbosity=1,
        gpu_id=1,
        **best_params
    )

    best_model.fit(X_test_scaled, y_test_scaled.ravel())

    # Save the model
    dump(best_model, './models/xgboost_optuna.joblib')

else:
    # Load the pre-trained model
    best_model = load('./models/xgboost_optuna.joblib')
# Out:
# [I 2023-12-19 23:34:39,168] A new study created in memory with name: no-name-0d490e3e-7b09-476d-b291-7fd91f356cc0
# [I 2023-12-19 23:34:47,532] Trial 0 finished with values: [54.959355372039546, -1271.8431547940465] and parameters: {'n_estimators': 100, 'learning_rate': 0.2966571826955631, 'loss': 'exponential'}.
# [I 2023-12-19 23:34:48,004] Trial 1 finished with values: [0.0523424079544545, -0.2122353913954298] and parameters: {'n_estimators': 5, 'learning_rate': 0.30191096098229786, 'loss': 'linear'}.
# [I 2023-12-19 23:34:57,136] Trial 2 finished with values: [16.81557390522911, -388.4439444261259] and parameters: {'n_estimators': 100, 'learning_rate': 0.1993583496659767, 'loss': 'exponential'}.
# [I 2023-12-19 23:35:17,554] Trial 3 finished with values: [0.09573784097733759, -1.217261369203773] and parameters: {'n_estimators': 200, 'learning_rate': 0.03201761143566927, 'loss': 'linear'}.
# [I 2023-12-19 23:35:20,404] Trial 4 finished with values: [0.14418963414969052, -2.3393912206085004] and parameters: {'n_estimators': 50, 'learning_rate': 0.2934419377251194, 'loss': 'linear'}.
# [I 2023-12-19 23:35:25,411] Trial 5 finished with values: [3.20176470972615, -73.15196678433752] and parameters: {'n_estimators': 50, 'learning_rate': 0.23803164258986848, 'loss': 'exponential'}.
# [I 2023-12-19 23:35:32,565] Trial 6 finished with values: [0.09666849441459353, -1.2388150400770566] and parameters: {'n_estimators': 100, 'learning_rate': 0.10436758502495347, 'loss': 'square'}.
# [I 2023-12-19 23:35:37,079] Trial 7 finished with values: [19.367802461082842, -447.5528372578826] and parameters: {'n_estimators': 50, 'learning_rate': 0.4039603475227762, 'loss': 'exponential'}.
# [I 2023-12-19 23:35:41,647] Trial 8 finished with values: [16.71505275561804, -386.1159029793447] and parameters: {'n_estimators': 50, 'learning_rate': 0.37327679402646974, 'loss': 'exponential'}.
# [I 2023-12-19 23:35:59,051] Trial 9 finished with values: [34.393313899856736, -795.5394403149639] and parameters: {'n_estimators': 200, 'learning_rate': 0.12672559852224774, 'loss': 'exponential'}.
# [I 2023-12-19 23:36:04,806] Trial 10 finished with values: [67.23741060203731, -1556.1994476925738] and parameters: {'n_estimators': 100, 'learning_rate': 0.3565451108764692, 'loss': 'square'}.
# [I 2023-12-19 23:36:08,380] Trial 11 finished with values: [0.1509851727975906, -2.496773977239567] and parameters: {'n_estimators': 100, 'learning_rate': 0.23936155905991222, 'loss': 'linear'}.
# [I 2023-12-19 23:36:22,718] Trial 12 finished with values: [222.1685790821543, -5144.361570942053] and parameters: {'n_estimators': 200, 'learning_rate': 0.254868208463302, 'loss': 'exponential'}.
# [I 2023-12-19 23:36:23,740] Trial 13 finished with values: [0.05451685527823979, -0.26259497754422245] and parameters: {'n_estimators': 10, 'learning_rate': 0.2729104935608092, 'loss': 'exponential'}.
# [I 2023-12-19 23:36:28,784] Trial 14 finished with values: [0.05537600288138408, -0.28249259348635314] and parameters: {'n_estimators': 50, 'learning_rate': 0.058340627058758435, 'loss': 'linear'}.
# [I 2023-12-19 23:36:29,749] Trial 15 finished with values: [0.05126442344269566, -0.18726957442982006] and parameters: {'n_estimators': 10, 'learning_rate': 0.12153209324800657, 'loss': 'linear'}.
# [I 2023-12-19 23:36:30,738] Trial 16 finished with values: [0.050400921825943794, -0.167271120761723] and parameters: {'n_estimators': 10, 'learning_rate': 0.038423501005952675, 'loss': 'exponential'}.
# [I 2023-12-19 23:36:40,479] Trial 17 finished with values: [3.8789172851038787, -88.83462926256585] and parameters: {'n_estimators': 100, 'learning_rate': 0.13234665912212723, 'loss': 'exponential'}.
# [I 2023-12-19 23:36:40,946] Trial 18 finished with values: [0.050718130281904805, -0.17461757905039077] and parameters: {'n_estimators': 5, 'learning_rate': 0.138931201160784, 'loss': 'exponential'}.
# [I 2023-12-19 23:36:45,527] Trial 19 finished with values: [13.893565085284088, -320.7710450709959] and parameters: {'n_estimators': 50, 'learning_rate': 0.3716393924173136, 'loss': 'exponential'}.
# [I 2023-12-19 23:36:47,260] Trial 20 finished with values: [0.10459193260400441, -1.4223196316712343] and parameters: {'n_estimators': 25, 'learning_rate': 0.47292351358824464, 'loss': 'linear'}.
# [I 2023-12-19 23:36:57,085] Trial 21 finished with values: [0.05474046741489741, -0.26777377150108017] and parameters: {'n_estimators': 100, 'learning_rate': 0.019833110346399695, 'loss': 'linear'}.
# [I 2023-12-19 23:36:59,518] Trial 22 finished with values: [0.05205233156937085, -0.2055173042086036] and parameters: {'n_estimators': 25, 'learning_rate': 0.06561257137553542, 'loss': 'exponential'}.
# [I 2023-12-19 23:37:01,649] Trial 23 finished with values: [0.07321464596871254, -0.6956305313463682] and parameters: {'n_estimators': 25, 'learning_rate': 0.3948473367980913, 'loss': 'linear'}.
# [I 2023-12-19 23:37:02,661] Trial 24 finished with values: [0.08755554051325252, -1.0277616004077705] and parameters: {'n_estimators': 10, 'learning_rate': 0.4381378875442721, 'loss': 'linear'}.
# [I 2023-12-19 23:37:03,597] Trial 25 finished with values: [0.05278628541987582, -0.22251546818316226] and parameters: {'n_estimators': 10, 'learning_rate': 0.33418133878049966, 'loss': 'square'}.
# [I 2023-12-19 23:37:08,447] Trial 26 finished with values: [0.10454673990519037, -1.4212729815250897] and parameters: {'n_estimators': 200, 'learning_rate': 0.2063611140870393, 'loss': 'square'}.
# [I 2023-12-19 23:37:13,547] Trial 27 finished with values: [0.1401068182014518, -2.244834355870537] and parameters: {'n_estimators': 50, 'learning_rate': 0.18942698775088218, 'loss': 'exponential'}.
# [I 2023-12-19 23:37:16,138] Trial 28 finished with values: [0.06856661071386018, -0.5879833470347762] and parameters: {'n_estimators': 25, 'learning_rate': 0.19554401569376303, 'loss': 'exponential'}.
# [I 2023-12-19 23:37:26,289] Trial 29 finished with values: [0.06860128817757402, -0.5887864673045646] and parameters: {'n_estimators': 100, 'learning_rate': 0.037616767803594645, 'loss': 'exponential'}.
# [I 2023-12-19 23:37:27,323] Trial 30 finished with values: [0.07628072120221406, -0.7666399681679552] and parameters: {'n_estimators': 10, 'learning_rate': 0.49022408480951674, 'loss': 'exponential'}.
# [I 2023-12-19 23:37:34,084] Trial 31 finished with values: [0.1424540806166686, -2.2991962907493075] and parameters: {'n_estimators': 100, 'learning_rate': 0.1233622899864075, 'loss': 'linear'}.
# [I 2023-12-19 23:37:38,500] Trial 32 finished with values: [19.676760347619712, -454.7082146879126] and parameters: {'n_estimators': 50, 'learning_rate': 0.4366245361630805, 'loss': 'exponential'}.
# [I 2023-12-19 23:37:43,866] Trial 33 finished with values: [0.10608498671563392, -1.4568983433911962] and parameters: {'n_estimators': 200, 'learning_rate': 0.14803653569254918, 'loss': 'linear'}.
# [I 2023-12-19 23:37:44,354] Trial 34 finished with values: [0.05055618929057791, -0.17086707140895907] and parameters: {'n_estimators': 5, 'learning_rate': 0.1734112132023659, 'loss': 'square'}.
# [I 2023-12-19 23:37:44,825] Trial 35 finished with values: [0.05072005001093606, -0.17466203943279446] and parameters: {'n_estimators': 5, 'learning_rate': 0.14388389261915005, 'loss': 'exponential'}.
# [I 2023-12-19 23:37:47,460] Trial 36 finished with values: [0.09771697764590531, -1.263097615716044] and parameters: {'n_estimators': 50, 'learning_rate': 0.3002544104908554, 'loss': 'linear'}.
# [I 2023-12-19 23:37:50,017] Trial 37 finished with values: [0.08789536667461656, -1.0356318783683487] and parameters: {'n_estimators': 25, 'learning_rate': 0.31626806890752057, 'loss': 'exponential'}.
# [I 2023-12-19 23:37:51,028] Trial 38 finished with values: [0.05532640062615019, -0.281343819258391] and parameters: {'n_estimators': 10, 'learning_rate': 0.31562986400343057, 'loss': 'linear'}.
# [I 2023-12-19 23:37:51,509] Trial 39 finished with values: [0.05144356982546586, -0.1914185540798099] and parameters: {'n_estimators': 5, 'learning_rate': 0.47203190506873205, 'loss': 'square'}.
# [I 2023-12-19 23:37:51,968] Trial 40 finished with values: [0.051662304157865824, -0.1964843794671176] and parameters: {'n_estimators': 5, 'learning_rate': 0.19251011055510325, 'loss': 'linear'}.
# [I 2023-12-19 23:37:52,968] Trial 41 finished with values: [0.05713775852644939, -0.3232943568633302] and parameters: {'n_estimators': 10, 'learning_rate': 0.3590443809592623, 'loss': 'exponential'}.
# [I 2023-12-19 23:37:53,940] Trial 42 finished with values: [0.05591529693212989, -0.29498249145306366] and parameters: {'n_estimators': 10, 'learning_rate': 0.21524075381511354, 'loss': 'linear'}.
# [I 2023-12-19 23:37:56,478] Trial 43 finished with values: [0.05842230825942255, -0.35304416603666033] and parameters: {'n_estimators': 25, 'learning_rate': 0.16900713384504498, 'loss': 'exponential'}.
# [I 2023-12-19 23:37:59,046] Trial 44 finished with values: [0.08525790517659895, -0.9745490146582612] and parameters: {'n_estimators': 25, 'learning_rate': 0.26802163493636616, 'loss': 'exponential'}.
# [I 2023-12-19 23:38:00,799] Trial 45 finished with values: [0.058040788189512284, -0.34420826892479406] and parameters: {'n_estimators': 25, 'learning_rate': 0.36575143548402156, 'loss': 'square'}.
# [I 2023-12-19 23:38:03,180] Trial 46 finished with values: [0.053374976381098276, -0.23614938465122814] and parameters: {'n_estimators': 25, 'learning_rate': 0.1761813483365454, 'loss': 'square'}.
# [I 2023-12-19 23:38:07,096] Trial 47 finished with values: [0.09069676098319261, -1.1005113796909587] and parameters: {'n_estimators': 100, 'learning_rate': 0.19751270038466373, 'loss': 'linear'}.
# [I 2023-12-19 23:38:09,798] Trial 48 finished with values: [0.11200270361881637, -1.5939509962332066] and parameters: {'n_estimators': 50, 'learning_rate': 0.3632250174668275, 'loss': 'linear'}.
# [I 2023-12-19 23:38:14,628] Trial 49 finished with values: [5.256648722528379, -120.74250040478265] and parameters: {'n_estimators': 50, 'learning_rate': 0.27735504588810966, 'loss': 'exponential'}.
# [I 2023-12-19 23:38:15,131] Trial 50 finished with values: [0.050881236460197404, -0.17839507209300343] and parameters: {'n_estimators': 5, 'learning_rate': 0.19251011055510325, 'loss': 'linear'}.
# [I 2023-12-19 23:38:17,706] Trial 51 finished with values: [0.08842987465936884, -1.0480109323978075] and parameters: {'n_estimators': 25, 'learning_rate': 0.31626806890752057, 'loss': 'exponential'}.
# [I 2023-12-19 23:38:22,762] Trial 52 finished with values: [0.15294422283345607, -2.542145023009129] and parameters: {'n_estimators': 50, 'learning_rate': 0.18942698775088218, 'loss': 'exponential'}.
# [I 2023-12-19 23:38:23,231] Trial 53 finished with values: [0.05037797355658197, -0.1667396453218486] and parameters: {'n_estimators': 5, 'learning_rate': 0.038423501005952675, 'loss': 'exponential'}.
# [I 2023-12-19 23:38:23,727] Trial 54 finished with values: [0.05020552494673972, -0.1627457842020159] and parameters: {'n_estimators': 5, 'learning_rate': 0.058340627058758435, 'loss': 'linear'}.
# [I 2023-12-19 23:38:38,924] Trial 55 finished with values: [112.79786199999965, -2611.366639859572] and parameters: {'n_estimators': 200, 'learning_rate': 0.19554401569376303, 'loss': 'exponential'}.
# [I 2023-12-19 23:38:39,403] Trial 56 finished with values: [0.05118549836427357, -0.1854416918949704] and parameters: {'n_estimators': 5, 'learning_rate': 0.18942698775088218, 'loss': 'exponential'}.
# [I 2023-12-19 23:38:39,886] Trial 57 finished with values: [0.050574345556568735, -0.1712875654035957] and parameters: {'n_estimators': 5, 'learning_rate': 0.046458066529929065, 'loss': 'square'}.
# [I 2023-12-19 23:38:55,015] Trial 58 finished with values: [159.12741747787155, -3684.3460653908487] and parameters: {'n_estimators': 200, 'learning_rate': 0.21524075381511354, 'loss': 'exponential'}.
# [I 2023-12-19 23:38:57,128] Trial 59 finished with values: [0.0641305735450713, -0.4852459785470544] and parameters: {'n_estimators': 25, 'learning_rate': 0.36575143548402156, 'loss': 'square'}.
# [I 2023-12-19 23:39:09,204] Trial 60 finished with values: [400.3636096736344, -9271.308173049989] and parameters: {'n_estimators': 200, 'learning_rate': 0.46017706299609307, 'loss': 'exponential'}.
# [I 2023-12-19 23:39:12,916] Trial 61 finished with values: [0.1406685147152284, -2.2578430885565823] and parameters: {'n_estimators': 100, 'learning_rate': 0.23936155905991222, 'loss': 'linear'}.
# [I 2023-12-19 23:39:13,880] Trial 62 finished with values: [0.052210231313563116, -0.20917421770728528] and parameters: {'n_estimators': 10, 'learning_rate': 0.3688134018121167, 'loss': 'square'}.
# [I 2023-12-19 23:39:14,873] Trial 63 finished with values: [0.051934992738814266, -0.20279977001893812] and parameters: {'n_estimators': 10, 'learning_rate': 0.138931201160784, 'loss': 'exponential'}.
# [I 2023-12-19 23:39:25,459] Trial 64 finished with values: [0.09340546293202878, -1.1632441521300518] and parameters: {'n_estimators': 100, 'learning_rate': 0.058340627058758435, 'loss': 'exponential'}.
# [I 2023-12-19 23:39:26,417] Trial 65 finished with values: [0.050346221939638613, -0.16600428683726642] and parameters: {'n_estimators': 10, 'learning_rate': 0.038423501005952675, 'loss': 'exponential'}.
# [I 2023-12-19 23:39:31,461] Trial 66 finished with values: [0.0554234838326445, -0.28359223891315666] and parameters: {'n_estimators': 50, 'learning_rate': 0.058340627058758435, 'loss': 'exponential'}.
# [I 2023-12-19 23:39:32,459] Trial 67 finished with values: [0.05226560146948233, -0.21045657488677838] and parameters: {'n_estimators': 10, 'learning_rate': 0.138931201160784, 'loss': 'linear'}.
# [I 2023-12-19 23:39:35,066] Trial 68 finished with values: [0.1356440929799881, -2.1414788996171934] and parameters: {'n_estimators': 25, 'learning_rate': 0.3081555527873658, 'loss': 'exponential'}.
# [I 2023-12-19 23:39:37,462] Trial 69 finished with values: [0.056400004943297284, -0.30620819215336925] and parameters: {'n_estimators': 25, 'learning_rate': 0.1761813483365454, 'loss': 'square'}.
# [I 2023-12-19 23:39:43,110] Trial 70 finished with values: [0.0620073075488577, -0.43607173749577766] and parameters: {'n_estimators': 100, 'learning_rate': 0.138931201160784, 'loss': 'square'}.
# [I 2023-12-19 23:39:51,253] Trial 71 finished with values: [64.98878085976571, -1504.1218176741393] and parameters: {'n_estimators': 100, 'learning_rate': 0.31626806890752057, 'loss': 'exponential'}.
# [I 2023-12-19 23:39:56,115] Trial 72 finished with values: [0.1543968978572866, -2.575788566455121] and parameters: {'n_estimators': 50, 'learning_rate': 0.1799710875289978, 'loss': 'linear'}.
# [I 2023-12-19 23:39:56,618] Trial 73 finished with values: [0.05087574056606942, -0.17826778873655003] and parameters: {'n_estimators': 5, 'learning_rate': 0.138931201160784, 'loss': 'exponential'}.
# [I 2023-12-19 23:40:06,497] Trial 74 finished with values: [0.05331624145974691, -0.23478910045423618] and parameters: {'n_estimators': 100, 'learning_rate': 0.019833110346399695, 'loss': 'linear'}.
# [I 2023-12-19 23:40:07,506] Trial 75 finished with values: [0.05976659192159781, -0.3841773961467745] and parameters: {'n_estimators': 10, 'learning_rate': 0.4048502571518067, 'loss': 'exponential'}.
# [I 2023-12-19 23:40:10,001] Trial 76 finished with values: [0.12853342982158136, -1.9767979482858609] and parameters: {'n_estimators': 25, 'learning_rate': 0.2971204028877587, 'loss': 'linear'}.
# [I 2023-12-19 23:40:13,195] Trial 77 finished with values: [0.09495623501565033, -1.19915959578694] and parameters: {'n_estimators': 50, 'learning_rate': 0.30236584460326205, 'loss': 'linear'}.
# [I 2023-12-19 23:40:18,185] Trial 78 finished with values: [3.625285382397515, -82.96058599892477] and parameters: {'n_estimators': 50, 'learning_rate': 0.23803164258986848, 'loss': 'exponential'}.
# [I 2023-12-19 23:40:20,606] Trial 79 finished with values: [0.14119255085559898, -2.2699796176264755] and parameters: {'n_estimators': 25, 'learning_rate': 0.3959121173214695, 'loss': 'linear'}.
# [I 2023-12-19 23:40:23,210] Trial 80 finished with values: [0.15151517789642668, -2.5090487457024206] and parameters: {'n_estimators': 25, 'learning_rate': 0.3000144609144861, 'loss': 'exponential'}.
# [I 2023-12-19 23:40:24,177] Trial 81 finished with values: [0.05290528529168273, -0.22527147161925543] and parameters: {'n_estimators': 10, 'learning_rate': 0.12153209324800657, 'loss': 'linear'}.
# [I 2023-12-19 23:40:26,189] Trial 82 finished with values: [0.06858146809913776, -0.5883274398834042] and parameters: {'n_estimators': 50, 'learning_rate': 0.49022408480951674, 'loss': 'linear'}.
# [I 2023-12-19 23:40:28,822] Trial 83 finished with values: [0.07887790180110907, -0.8267899376260981] and parameters: {'n_estimators': 25, 'learning_rate': 0.2063611140870393, 'loss': 'exponential'}.
# [I 2023-12-19 23:40:32,841] Trial 84 finished with values: [0.09993636967396616, -1.3144981085274812] and parameters: {'n_estimators': 200, 'learning_rate': 0.19554401569376303, 'loss': 'linear'}.
# [I 2023-12-19 23:40:33,346] Trial 85 finished with values: [0.05128673676963432, -0.18778634478242484] and parameters: {'n_estimators': 5, 'learning_rate': 0.30191096098229786, 'loss': 'exponential'}.
# [I 2023-12-19 23:40:34,361] Trial 86 finished with values: [0.05679237937126381, -0.31529547313351536] and parameters: {'n_estimators': 10, 'learning_rate': 0.3590443809592623, 'loss': 'exponential'}.
# [I 2023-12-19 23:40:36,706] Trial 87 finished with values: [0.11164067405418188, -1.5855664937211462] and parameters: {'n_estimators': 100, 'learning_rate': 0.33418133878049966, 'loss': 'square'}.
# [I 2023-12-19 23:40:39,150] Trial 88 finished with values: [0.05078147567835176, -0.17608464054900952] and parameters: {'n_estimators': 25, 'learning_rate': 0.030337619533150978, 'loss': 'exponential'}.
# [I 2023-12-19 23:40:40,955] Trial 89 finished with values: [0.12459855293649584, -1.8856673104857222] and parameters: {'n_estimators': 100, 'learning_rate': 0.49762825995203414, 'loss': 'linear'}.
# [I 2023-12-19 23:40:42,721] Trial 90 finished with values: [0.07650969721238056, -0.7719429879209989] and parameters: {'n_estimators': 50, 'learning_rate': 0.4039603475227762, 'loss': 'linear'}.
# [I 2023-12-19 23:40:43,707] Trial 91 finished with values: [0.05626555814742875, -0.30309444231684357] and parameters: {'n_estimators': 10, 'learning_rate': 0.3590443809592623, 'loss': 'exponential'}.
# [I 2023-12-19 23:40:44,657] Trial 92 finished with values: [0.05805753998268973, -0.34459623572557074] and parameters: {'n_estimators': 10, 'learning_rate': 0.4959928260622178, 'loss': 'square'}.
# [I 2023-12-19 23:40:49,192] Trial 93 finished with values: [0.097538646310869, -1.2589675123414743] and parameters: {'n_estimators': 100, 'learning_rate': 0.19251011055510325, 'loss': 'linear'}.
# [I 2023-12-19 23:40:49,656] Trial 94 finished with values: [0.05040514570945042, -0.16736894471128827] and parameters: {'n_estimators': 5, 'learning_rate': 0.138931201160784, 'loss': 'exponential'}.
# [I 2023-12-19 23:40:51,595] Trial 95 finished with values: [0.0783985771183968, -0.8156889132930412] and parameters: {'n_estimators': 25, 'learning_rate': 0.3948473367980913, 'loss': 'linear'}.
# [I 2023-12-19 23:40:56,569] Trial 96 finished with values: [0.05888944007502153, -0.3638628070095522] and parameters: {'n_estimators': 50, 'learning_rate': 0.058340627058758435, 'loss': 'linear'}.
# [I 2023-12-19 23:40:59,111] Trial 97 finished with values: [0.19956777142230503, -3.6219332459931888] and parameters: {'n_estimators': 25, 'learning_rate': 0.3948473367980913, 'loss': 'exponential'}.
# [I 2023-12-19 23:41:08,371] Trial 98 finished with values: [14.619154930788447, -337.57550105099006] and parameters: {'n_estimators': 100, 'learning_rate': 0.19554401569376303, 'loss': 'exponential'}.
# [I 2023-12-19 23:41:10,773] Trial 99 finished with values: [0.051595883143345705, -0.19494608752220488] and parameters: {'n_estimators': 25, 'learning_rate': 0.06561257137553542, 'loss': 'square'}.
# Best values: [0.05020552494673972, -0.1627457842020159] | best params: {'n_estimators': 5, 'learning_rate': 0.058340627058758435, 'loss': 'linear'}
# [23:41:11] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1700181129011/work/src/learner.cc:767:
# Parameters: { "loss" } are not used.

# %%
import pickle

# best_params = grid_search.best_params_
# best_model = grid_search.best_estimator_

print(best_model)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=1, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.058340627058758435,
#              loss='linear', max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, n_estimators=5, n_jobs=None,
#              num_parallel_tree=None, predictor=None, ...)

# %%
def predict(X_test_scaled, model):
    # Make Predictions
    return scale_y(best_model.predict(X_test_scaled).reshape(-1, 1))

def evaluate(y_test, predictions):

    # # Use np.clip to limit values between 0 and 100
    # predictions_clipped = np.clip(predictions, 0, 100)

    # Evaluate the Model
    mse = mean_squared_error(y_test, predictions)
    print(f'Mean Squared Error: {mse.item()}')

    r2 = r2_score(y_test, predictions)
    print(f'r2: {r2.item()}')

    # Plotting
    plt.plot(y_test, label='Test')
    plt.plot(predictions, label='Prediction')

    # Adding labels and title
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('Prediction vs Test')

    # Adding legend
    plt.legend()

    # Display the plot
    plt.show()

def predict_and_evaluate(X_test_scaled, y_test, model):
    predictions = predict(X_test_scaled, model)
    evaluate(y_test, predictions)

predict_and_evaluate(X_test_scaled, y_test_scaled, best_model)
# Out:
# Mean Squared Error: 0.04964980462327757
# r2: -0.14987545839650984

# %%
from matplotlib import pyplot as plt

def plot_importances(model, feature_names):
    # Get feature importances from the model
    importances = model.feature_importances_

    # Sort indices and feature names
    indices = np.argsort(importances)[::-1]
    feature_names = [feature_names[i] for i in indices]

    # Create a DataFrame for better visualization
    df_importances = pd.DataFrame({'Feature': feature_names, 'Importance': importances[indices]})

    # Display the top 20 features
    print(df_importances.head(20))

    # Create a horizontal bar plot
    plt.figure(figsize=(10, 8))
    plt.barh(range(len(feature_names)), importances[indices], align='center')

    # Set y-axis labels
    plt.yticks(range(len(feature_names)), feature_names)

    # Display the plot
    plt.xlabel('Feature Importance')
    plt.ylabel('Feature')
    plt.title('Top 20 Feature Importances')
    plt.show()

# Assuming best_model is your trained XGBoost model and X is your feature matrix
plot_importances(best_model, X.columns.tolist())
# Out:
#                  Feature  Importance
# 0       percentage_lag_1    0.990948
# 1       percentage_lag_5    0.001747
# 2       percentage_lag_2    0.001741
# 3       percentage_lag_6    0.001340
# 4       percentage_lag_3    0.001062
# 5       percentage_30-60    0.000911
# 6       percentage_lag_4    0.000869
# 7   precipitation_60-120    0.000731
# 8     precipitation_0-60    0.000499
# 9       percentage_60-90    0.000083
# 10         precipitation    0.000069
# 11                 month    0.000000
# 12             dayofweek    0.000000
# 13                  hour    0.000000

# %%
from datetime import timedelta
def predict_one_step(X_test:pd.DataFrame, X_weather:pd.DataFrame):
    # X_test_filtered = X_test.drop(columns=['percentage_delta', 'percentage', 'timestamp'])
    X_test_filtered = X_test.drop(columns=['percentage', 'timestamp'])
    X_test_scaled = scale_X(X_test_filtered.tail(1))
    input = X_test.tail(1)

    percentage_delta = scale_y(predict(X_test_scaled, best_model)[0].reshape(-1, 1))

    # print('here', percentage_delta_clipped)

    future_timestamp = input['timestamp'].values[0] + + np.timedelta64(5, 'm')
    precipitation_row = X_weather[future_timestamp == X_weather['timestamp']].iloc[0]

    new_row = {
        'timestamp':future_timestamp,
        'precipitation': precipitation_row['precipitation'],
        # 'percentage_delta': percentage_delta,
        # 'percentage': input['percentage'].values[0] + percentage_delta
        'percentage': input['percentage'].values[0]
        }
    # df_unprocessed = pd.concat([X_test[['timestamp', 'percentage', 'percentage_delta', 'precipitation' ]], pd.DataFrame([new_row])], ignore_index=True)
    df_unprocessed = pd.concat([X_test[['timestamp', 'percentage', 'precipitation' ]], pd.DataFrame([new_row])], ignore_index=True)
    return df_features_of_df(df_unprocessed)
    
X_original = df_features_of_df(df_reduced)
first_nan_index = X_original['precipitation_60-120'].notna().idxmax()
X_result = X_original.copy()
X_result = X_result[X_result.index <= first_nan_index]
for i in range(0,int(len(X_original)/50)):
    X_result = predict_one_step(X_result,X_original)


# X_result[['percentage_delta', 'precipitation']].plot()
X_result[['percentage', 'precipitation']].plot()
X_result
# Out:
#                  timestamp  precipitation  percentage
# 208297 2021-01-01 08:00:00            0.0       0.000
# 208298 2021-01-01 08:05:00            0.0       0.000
# 208299 2021-01-01 08:10:00            0.0       0.000
# 208300 2021-01-01 08:15:00            0.0       0.000
# 208301 2021-01-01 08:20:00            0.0       0.000
# ...                    ...            ...         ...
# 409004 2022-12-01 07:35:00            0.0       1.754
# 409005 2022-12-01 07:40:00            0.0       1.754
# 409006 2022-12-01 07:45:00            0.0       1.754
# 409007 2022-12-01 07:50:00            0.0       1.754
# 409008 2022-12-01 07:55:00            0.0       1.754
#
# [200712 rows x 3 columns]
#              timestamp  percentage  precipitation
# 0  2021-01-01 08:00:00       0.000            0.0
# 1  2021-01-01 08:05:00       0.000            0.0
# 2  2021-01-01 08:10:00       0.000            0.0
# 3  2021-01-01 08:15:00       0.000            0.0
# 4  2021-01-01 08:20:00       0.000            0.0
# 5  2021-01-01 08:25:00       1.503            0.0
# 6  2021-01-01 08:30:00       1.754            0.0
# 7  2021-01-01 08:35:00       1.754            0.0
# 8  2021-01-01 08:40:00       1.754            0.0
# 9  2021-01-01 08:45:00       2.004            0.0
# 10 2021-01-01 08:50:00       2.296            0.0
# 11 2021-01-01 08:55:00       2.589            0.0
# 12 2021-01-01 09:00:00       2.632            0.0
# 13 2021-01-01 09:05:00       2.632            0.0
# 14 2021-01-01 09:10:00       2.632            0.0
#              timestamp  percentage  precipitation
# 0  2021-01-01 08:00:00       0.000            0.0
# 1  2021-01-01 08:05:00       0.000            0.0
# 2  2021-01-01 08:10:00       0.000            0.0
# 3  2021-01-01 08:15:00       0.000            0.0
# 4  2021-01-01 08:20:00       0.000            0.0
# 5  2021-01-01 08:25:00       1.503            0.0
# 6  2021-01-01 08:30:00       1.754            0.0
# 7  2021-01-01 08:35:00       1.754            0.0
# 8  2021-01-01 08:40:00       1.754            0.0
# 9  2021-01-01 08:45:00       2.004            0.0
# 10 2021-01-01 08:50:00       2.296            0.0
# 11 2021-01-01 08:55:00       2.589            0.0
# 12 2021-01-01 09:00:00       2.632            0.0
# 13 2021-01-01 09:05:00       2.632            0.0
# 14 2021-01-01 09:10:00       2.632            0.0
# 15 2021-01-01 09:15:00       2.632            0.0
#              timestamp  percentage  precipitation
# 0  2021-01-01 08:00:00       0.000            0.0
# 1  2021-01-01 08:05:00       0.000            0.0
# 2  2021-01-01 08:10:00       0.000            0.0
# 3  2021-01-01 08:15:00       0.000            0.0
# 4  2021-01-01 08:20:00       0.000            0.0
# 5  2021-01-01 08:25:00       1.503            0.0
# 6  2021-01-01 08:30:00       1.754            0.0
# 7  2021-01-01 08:35:00       1.754            0.0
# 8  2021-01-01 08:40:00       1.754            0.0
# 9  2021-01-01 08:45:00       2.004            0.0
# 10 2021-01-01 08:50:00       2.296            0.0
# 11 2021-01-01 08:55:00       2.589            0.0
# 12 2021-01-01 09:00:00       2.632            0.0
# 13 2021-01-01 09:05:00       2.632            0.0
# 14 2021-01-01 09:10:00       2.632            0.0
# 15 2021-01-01 09:15:00       2.632            0.0
# 16 2021-01-01 09:20:00       2.632            0.0
#              timestamp  percentage  precipitation
# 0  2021-01-01 08:00:00       0.000            0.0
# 1  2021-01-01 08:05:00       0.000            0.0
# 2  2021-01-01 08:10:00       0.000            0.0
# 3  2021-01-01 08:15:00       0.000            0.0
# 4  2021-01-01 08:20:00       0.000            0.0
# 5  2021-01-01 08:25:00       1.503            0.0
# 6  2021-01-01 08:30:00       1.754            0.0
# 7  2021-01-01 08:35:00       1.754            0.0
# 8  2021-01-01 08:40:00       1.754            0.0
# 9  2021-01-01 08:45:00       2.004            0.0
# 10 2021-01-01 08:50:00       2.296            0.0
# 11 2021-01-01 08:55:00       2.589            0.0
# 12 2021-01-01 09:00:00       2.632            0.0
# 13 2021-01-01 09:05:00       2.632            0.0
# 14 2021-01-01 09:10:00       2.632            0.0
# 15 2021-01-01 09:15:00       2.632            0.0
# 16 2021-01-01 09:20:00       2.632            0.0
# 17 2021-01-01 09:25:00       2.632            0.0
#              timestamp  percentage  precipitation
# 0  2021-01-01 08:00:00       0.000            0.0
# 1  2021-01-01 08:05:00       0.000            0.0
# 2  2021-01-01 08:10:00       0.000            0.0
# 3  2021-01-01 08:15:00       0.000            0.0
# 4  2021-01-01 08:20:00       0.000            0.0
# 5  2021-01-01 08:25:00       1.503            0.0
# 6  2021-01-01 08:30:00       1.754            0.0
# 7  2021-01-01 08:35:00       1.754            0.0
# 8  2021-01-01 08:40:00       1.754            0.0
# 9  2021-01-01 08:45:00       2.004            0.0
# 10 2021-01-01 08:50:00       2.296            0.0
# 11 2021-01-01 08:55:00       2.589            0.0
# 12 2021-01-01 09:00:00       2.632            0.0
# 13 2021-01-01 09:05:00       2.632            0.0
# 14 2021-01-01 09:10:00       2.632            0.0
# 15 2021-01-01 09:15:00       2.632            0.0
# 16 2021-01-01 09:20:00       2.632            0.0
# 17 2021-01-01 09:25:00       2.632            0.0
# 18 2021-01-01 09:30:00       2.632            0.0
#              timestamp  percentage  precipitation
# 0  2021-01-01 08:00:00       0.000            0.0
# 1  2021-01-01 08:05:00       0.000            0.0
# 2  2021-01-01 08:10:00       0.000            0.0
# 3  2021-01-01 08:15:00       0.000            0.0
# 4  2021-01-01 08:20:00       0.000            0.0
# 5  2021-01-01 08:25:00       1.503            0.0
# 6  2021-01-01 08:30:00       1.754            0.0
# 7  2021-01-01 08:35:00       1.754            0.0
# 8  2021-01-01 08:40:00       1.754            0.0
# 9  2021-01-01 08:45:00       2.004            0.0
# 10 2021-01-01 08:50:00       2.296            0.0
# 11 2021-01-01 08:55:00       2.589            0.0
# 12 2021-01-01 09:00:00       2.632            0.0
# 13 2021-01-01 09:05:00       2.632            0.0
# 14 2021-01-01 09:10:00       2.632            0.0
# 15 2021-01-01 09:15:00       2.632            0.0
# 16 2021-01-01 09:20:00       2.632            0.0
# 17 2021-01-01 09:25:00       2.632            0.0
# 18 2021-01-01 09:30:00       2.632            0.0
# 19 2021-01-01 09:35:00       2.632            0.0
#              timestamp  percentage  precipitation
# 0  2021-01-01 08:00:00       0.000            0.0
# 1  2021-01-01 08:05:00       0.000            0.0
# 2  2021-01-01 08:10:00       0.000            0.0
# 3  2021-01-01 08:15:00       0.000            0.0
# 4  2021-01-01 08:20:00       0.000            0.0
# 5  2021-01-01 08:25:00       1.503            0.0
# 6  2021-01-01 08:30:00       1.754            0.0
# 7  2021-01-01 08:35:00       1.754            0.0
# 8  2021-01-01 08:40:00       1.754            0.0
# 9  2021-01-01 08:45:00       2.004            0.0
# 10 2021-01-01 08:50:00       2.296            0.0
# 11 2021-01-01 08:55:00       2.589            0.0
# 12 2021-01-01 09:00:00       2.632            0.0
# 13 2021-01-01 09:05:00       2.632            0.0
# 14 2021-01-01 09:10:00       2.632            0.0
# 15 2021-01-01 09:15:00       2.632            0.0
rows x 3 columns]
#                timestamp  percentage  precipitation
# 0    2021-01-01 08:00:00       0.000            0.0
# 1    2021-01-01 08:05:00       0.000            0.0
# 2    2021-01-01 08:10:00       0.000            0.0
# 3    2021-01-01 08:15:00       0.000            0.0
# 4    2021-01-01 08:20:00       0.000            0.0
# ...                  ...         ...            ...
# 4022 2021-01-15 07:10:00       2.632            0.0
# 4023 2021-01-15 07:15:00       2.632            0.0
# 4024 2021-01-15 07:20:00       2.632            0.0
# 4025 2021-01-15 07:25:00       2.632            0.0
# 4026 2021-01-15 07:30:00       2.632            0.0
#
# [4027 rows x 3 columns]
#                timestamp  percentage  precipitation
# 0    2021-01-01 08:00:00       0.000            0.0
# 1    2021-01-01 08:05:00       0.000            0.0
# 2    2021-01-01 08:10:00       0.000            0.0
# 3    2021-01-01 08:15:00       0.000            0.0
# 4    2021-01-01 08:20:00       0.000            0.0
# ...                  ...         ...            ...
# 4023 2021-01-15 07:15:00       2.632            0.0
# 4024 2021-01-15 07:20:00       2.632            0.0
# 4025 2021-01-15 07:25:00       2.632            0.0
# 4026 2021-01-15 07:30:00       2.632            0.0
# 4027 2021-01-15 07:35:00       2.632            0.0
#
# [4028 rows x 3 columns]
#                timestamp  percentage  precipitation  hour  dayofweek  month  \
# 0    2021-01-01 08:00:00       0.000            0.0     8          8      8
# 1    2021-01-01 08:05:00       0.000            0.0     8          8      8
# 2    2021-01-01 08:10:00       0.000            0.0     8          8      8
# 3    2021-01-01 08:15:00       0.000            0.0     8          8      8
# 4    2021-01-01 08:20:00       0.000            0.0     8          8      8
# ...                  ...         ...            ...   ...        ...    ...
# 4023 2021-01-15 07:15:00       2.632            0.0     7          7      7
# 4024 2021-01-15 07:20:00       2.632            0.0     7          7      7
# 4025 2021-01-15 07:25:00       2.632            0.0     7          7      7
# 4026 2021-01-15 07:30:00       2.632            0.0     7          7      7
# 4027 2021-01-15 07:35:00       2.632            0.0     7          7      7
#
#       precipitation_0-60  precipitation_60-120  percentage_30-60  \
# 0                    0.0                   NaN               NaN
# 1                    0.0                   NaN               NaN
# 2                    0.0                   NaN               NaN
# 3                    0.0                   NaN               NaN
# 4                    0.0                   NaN               NaN
# ...                  ...                   ...               ...
# 4023                 0.0                   0.0            15.792
# 4024                 0.0                   0.0            15.792
# 4025                 0.0                   0.0            15.792
# 4026                 0.0                   0.0            15.792
# 4027                 0.0                   0.0            15.792
#
#       percentage_60-90  percentage_lag_1  percentage_lag_2  percentage_lag_3  \
# 0                  NaN               NaN               NaN               NaN
# 1                  NaN             0.000               NaN               NaN
# 2                  NaN             0.000             0.000               NaN
# 3                  NaN             0.000             0.000             0.000
# 4                  NaN             0.000             0.000             0.000
# ...                ...               ...               ...               ...
# 4023            15.792             2.632             2.632             2.632
# 4024            15.792             2.632             2.632             2.632
# 4025            15.792             2.632             2.632             2.632
# 4026            15.792             2.632             2.632             2.632
# 4027            15.792             2.632             2.632             2.632
#
#       percentage_lag_4  percentage_lag_5  percentage_lag_6
# 0                  NaN               NaN               NaN
# 1                  NaN               NaN               NaN
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4                0.000               NaN               NaN
# ...                ...               ...               ...
# 4023             2.632             2.632             2.632
# 4024             2.632             2.632             2.632
# 4025             2.632             2.632             2.632
# 4026             2.632             2.632             2.632
# 4027             2.632             2.632             2.632
#
# [4028 rows x 16 columns]
